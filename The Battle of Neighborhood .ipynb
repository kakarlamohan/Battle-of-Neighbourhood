# %% [markdown]
# # The Battle of Neighborhood

# %% [markdown]
# ## Introduction
# An Indian restaurant chain owner (Client / Stakeholder) is willing to open a restaurant in US, but not able to make a decision in which city. This project helps the stakeholder in identyfing the city where he should open restaurant for a flourshing business.

# %% [markdown]
# ## Business Problem section
# US has 52 states and 300+ plus cities having more that 100K population, project is to evaluate various cities and its Metropolitan Statistical Area with Indian American Population. As latest data is not available for the same will populate the same based on the growth rate as per last census. Post which we will select the city having highest Indian American population where the client can open the restaurant. Will be using the Foursquare data to understand where most of the restaurants are established and select the same neighbourhood to open the restaurant.

# %% [markdown]
# ### U.S. metropolitan city with largest Asian Indian populations data will be used to select the city where the stakeholder can open an Indian Restaurant

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # module to convert an address into␣,→latitude and longitude values
# libraries for displaying images
from IPython.display import Image
from IPython.core.display import HTML
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0          conda-forge
#     geopy:           2.0.0-pyh9f0ad1d_0 conda-forge
#     python_abi:      3.6-1_cp36m        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0               --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0              --> 1.1.1g-h516909a_1        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                    --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# # Additional data that i will be using is of U.S. metropolitan city with largest Asian Indian populations is uploaded in below cell

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Metropolitan_Statistical_Area  Indian_American_Population  Total_population  \
# 0                       Atlanta                       78980           5268860
# 1                        Austin                       23503           1716289
# 2                     Baltimore                       32193           2710489
# 3                        Boston                       62598           4552402
# 4                    Bridgeport                       15439            916829
#
#    Percentage_of_Total_population
# 0                           0.015
# 1                           0.014
# 2                           0.012
# 3                           0.014
# 4                           0.017

# %%
df_data_2.count()
# Out:
# Metropolitan_Statistical_Area     40
# Indian_American_Population        40
# Total_population                  40
# Percentage_of_Total_population    40
# dtype: int64

# %%
df_data_2['Indian_American_Population'].max()
# Out:
# 526133

# %% [markdown]
# ## Let us identify which city is having maximum Indians in US

# %%
print(df_data_2[df_data_2.Indian_American_Population == df_data_2.Indian_American_Population.max()])
# Out:
#    Metropolitan_Statistical_Area  Indian_American_Population  \
# 22                      New York                      526133
#
#     Total_population  Percentage_of_Total_population
# 22          18897109                           0.028

# %% [markdown]
# ## Define Foursquare Credentials and Version details of developer account

# %%
CLIENT_ID = '40ABELL2KJ4QKL1KZSUCEKNLXLI0L32EN1HE3MQWU1ZK5YGV' # your Foursquare ID
CLIENT_SECRET = 'PXKPQQRB0BDRB5TXJHR15S3D2LWAHY0LZ5NA5QLOWQNMCJD4' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

# %% [markdown]
# So let’s start by converting the selected restaurant’s address to its latitude and longitude coordinates. In order
# to define an instance of the geocoder, we need to define a user_agent. We will name our agent
# foursquare_agent, as shown below.

# %%
address = '102 North End Ave, New York, NY'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7149555 -74.0153365

# %%
search_query = 'Indian'
LIMIT = 100
radius = 10000
print(search_query + ' .... OK!')
# Out:
# Indian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=40ABELL2KJ4QKL1KZSUCEKNLXLI0L32EN1HE3MQWU1ZK5YGV&client_secret=PXKPQQRB0BDRB5TXJHR15S3D2LWAHY0LZ5NA5QLOWQNMCJD4&ll=40.7149555,-74.0153365&v=20180605&query=Indian&radius=10000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f438f690f769205f8dca706'},
#  'response': {'venues': [{'id': '5072fe2eb0ed0fcce2497f30',
#     'name': 'Indian Biryani Delights (Cart)',
#     'location': {'address': 'Water St',
#      'crossStreet': 'btwn Maiden Lane & Pine St',
#      'lat': 40.71316451366987,
#      'lng': -74.01021890317702,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71316451366987,
#        'lng': -74.01021890317702}],
#      'distance': 475,
#      'postalCode': '10005',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Water St (btwn Maiden Lane & Pine St)',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '5d18e90b96ba5e00232c527f',
#     'name': 'Bismilla Indian Biryani House',
#     'location': {'lat': 40.715357202741,
#      'lng': -74.01131492125047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715357202741,
#        'lng': -74.01131492125047}],
#      'distance': 342,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10007', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '510aad1ae4b0bfb2583169b9',
#     'name': 'A Saffron Thread Fresh Indian',
#     'location': {'address': '98 Chambers St',
#      'crossStreet': 'at Church St',
#      'lat': 40.71482256030567,
#      'lng': -74.00768924078284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71482256030567,
#        'lng': -74.00768924078284}],
#      'distance': 645,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['98 Chambers St (at Church St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '275521',
#      'url': 'https://www.seamless.com/menu/a-saffron-thread-98-chambers-st-new-york/275521?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=275521',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '432263795'},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '573f435b498e03b8bb8582c7',
#     'name': 'Indian king Biriyani House',
#     'location': {'address': '140 Broadway',
#      'lat': 40.70253964211186,
#      'lng': -74.01272653736166,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70253964211186,
#        'lng': -74.01272653736166}],
#      'distance': 1399,
#      'postalCode': '10005',
#      'cc': 'US',
#      'neighborhood': 'Tribeca',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['140 Broadway',
#       'New York, NY 10005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '54a4690e498e43a77f503eba',
#     'name': 'National Museum of the American Indian Museum Store',
#     'location': {'address': '1 Bowling Grn',
#      'lat': 40.704048,
#      'lng': -74.013737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.704048,
#        'lng': -74.013737},
#       {'label': 'entrance', 'lat': 40.703691, 'lng': -74.013749}],
#      'distance': 1221,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 Bowling Grn',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b1b',
#       'name': 'Souvenir Shop',
#       'pluralName': 'Souvenir Shops',
#       'shortName': 'Souvenir Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '45719c4bf964a520693e1fe3',
#     'name': 'National Museum of the American Indian',
#     'location': {'address': '1 Bowling Grn',
#      'crossStreet': 'btwn Broadway & State St',
#      'lat': 40.7043035374255,
#      'lng': -74.01375942059204,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7043035374255,
#        'lng': -74.01375942059204}],
#      'distance': 1193,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 Bowling Grn (btwn Broadway & State St)',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d181941735',
#       'name': 'Museum',
#       'pluralName': 'Museums',
#       'shortName': 'Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '574eab2a498e3f5530cfdbca',
#     'name': 'Indian Beautiful Art (IBA) Crafts PVT Ltd',
#     'location': {'address': '100 Church St',
#      'lat': 40.71228057311295,
#      'lng': -74.01012897491455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71228057311295,
#        'lng': -74.01012897491455}],
#      'distance': 530,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['100 Church St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4a948b83f964a520f32120e3',
#     'name': 'Indian Express',
#     'location': {'address': '18 Murray St',
#      'crossStreet': 'Church St.',
#      'lat': 40.71341323852539,
#      'lng': -74.00846862792969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71341323852539,
#        'lng': -74.00846862792969}],
#      'distance': 604,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 Murray St (Church St.)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '574e8ba2cd10da9c722374fb',
#     'name': 'Indian Beautiful Art (IBA) Crafts PVT Ltd',
#     'location': {'address': '100 Church St',
#      'lat': 40.71613521878094,
#      'lng': -74.00660991668701,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71613521878094,
#        'lng': -74.00660991668701}],
#      'distance': 747,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['100 Church St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f4941735',
#       'name': 'Design Studio',
#       'pluralName': 'Design Studios',
#       'shortName': 'Design',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/design_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '506a2625498e3c434686abbc',
#     'name': 'Asya Indian Restaurant',
#     'location': {'address': '46 Henry St',
#      'lat': 40.699607,
#      'lng': -73.99211,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.699607,
#        'lng': -73.99211}],
#      'distance': 2600,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['46 Henry St',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '266126',
#      'url': 'https://www.seamless.com/menu/asya-46-henry-st-brooklyn/266126?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=266126',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '94617937'},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '575dea4c498e2739e43a27e2',
#     'name': 'Aahar Indian Cuisine',
#     'location': {'address': '10 Murray St',
#      'crossStreet': 'Broadway',
#      'lat': 40.71330656515891,
#      'lng': -74.00799405698501,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71330656515891,
#        'lng': -74.00799405698501}],
#      'distance': 646,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 Murray St (Broadway)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '333939',
#      'url': 'https://www.seamless.com/menu/aahar-indian-cuisine-10-murray-st-new-york/333939?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=333939',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '5730b7a9498ef7b05c09c07f',
#     'name': "Baluchi's Indian",
#     'location': {'address': '176 Church Street',
#      'crossStreet': 'between Duane and Reade Streets',
#      'lat': 40.71567153930664,
#      'lng': -74.00765228271484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71567153930664,
#        'lng': -74.00765228271484}],
#      'distance': 653,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['176 Church Street (between Duane and Reade Streets)',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4b12cb6ff964a5204a8e23e3',
#     'name': 'Ruchi Indian Cuisine',
#     'location': {'address': '120 Cedar St',
#      'crossStreet': 'btwn Greenwich St. & Trinity Pl.',
#      'lat': 40.70996196046026,
#      'lng': -74.01296935042234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70996196046026,
#        'lng': -74.01296935042234}],
#      'distance': 590,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Cedar St (btwn Greenwich St. & Trinity Pl.)',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '79935',
#      'url': 'https://www.seamless.com/menu/ruchi-120-cedar-st-new-york/79935?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=79935',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '337710444'},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '5df11a0d80d83900088ffbcc',
#     'name': 'Indian Biryani House',
#     'location': {'lat': 40.728253,
#      'lng': -74.007321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.728253,
#        'lng': -74.007321}],
#      'distance': 1627,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10014', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '5a09edbb419a9e6bb1ba62a1',
#     'name': 'Indian Grill & Biryani House',
#     'location': {'lat': 40.70424479657133,
#      'lng': -74.00911714045556,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70424479657133,
#        'lng': -74.00911714045556}],
#      'distance': 1302,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10004', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '553fb844498e6cc1b6da5ce4',
#     'name': 'Indian Biryani House',
#     'location': {'lat': 40.704955,
#      'lng': -74.013003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.704955,
#        'lng': -74.013003}],
#      'distance': 1130,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '50a5221fe4b0dea0468d43d1',
#     'name': 'smart indian cuisine',
#     'location': {'address': '53 Nassau St',
#      'crossStreet': 'maiden lane & liberty',
#      'lat': 40.709022,
#      'lng': -74.009117,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.709022,
#        'lng': -74.009117},
#       {'label': 'entrance', 'lat': 40.708986, 'lng': -74.009055}],
#      'distance': 843,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['53 Nassau St (maiden lane & liberty)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4c952ca038dd8cfab44cd062',
#     'name': 'Indian Larry Motorcycles NYC',
#     'location': {'address': '70 N 15th St',
#      'crossStreet': 'at Ainslie St.',
#      'lat': 40.712322311660124,
#      'lng': -73.95131959752116,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.712322311660124,
#        'lng': -73.95131959752116}],
#      'distance': 5409,
#      'postalCode': '11222',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['70 N 15th St (at Ainslie St.)',
#       'Brooklyn, NY 11222',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4d0e6159bf0c8eec2188282a',
#     'name': 'Indian Restaurant',
#     'location': {'address': '369 Broome St',
#      'lat': 40.71997833251953,
#      'lng': -73.99590301513672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71997833251953,
#        'lng': -73.99590301513672}],
#      'distance': 1732,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['369 Broome St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '537df32c498ea5ac2006e4de',
#     'name': 'CKGS Indian Visa Application Center',
#     'location': {'address': '235 W 23rd St',
#      'lat': 40.744725182938325,
#      'lng': -73.99679561537461,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744725182938325,
#        'lng': -73.99679561537461},
#       {'label': 'entrance', 'lat': 40.744739, 'lng': -73.996787}],
#      'distance': 3664,
#      'postalCode': '10011',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['235 W 23rd St',
#       'New York, NY 10011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12c951735',
#       'name': 'Embassy / Consulate',
#       'pluralName': 'Embassies / Consulates',
#       'shortName': 'Embassy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/embassy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4db5b3851e7248d135ba1fe9',
#     'name': 'Indian Food Truck',
#     'location': {'address': 'Christopher Columbus St',
#      'crossStreet': 'Hudson Street',
#      'lat': 40.71289231329906,
#      'lng': -74.03380772420626,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71289231329906,
#        'lng': -74.03380772420626}],
#      'distance': 1575,
#      'cc': 'US',
#      'city': 'Jersey City',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Christopher Columbus St (Hudson Street)',
#       'Jersey City, NJ',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4c6ec437c52437042cf42beb',
#     'name': 'Indian fast food cart',
#     'location': {'address': '53rd street',
#      'crossStreet': 'Park avenue',
#      'lat': 40.75946861543554,
#      'lng': -73.97225608333729,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75946861543554,
#        'lng': -73.97225608333729}],
#      'distance': 6144,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['53rd street (Park avenue)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4116be80f964a520f90b1fe3',
#     'name': 'Panna II Garden Indian Restaurant',
#     'location': {'address': '93 1st Ave',
#      'crossStreet': 'btwn 5th & 6th St',
#      'lat': 40.726272990045985,
#      'lng': -73.98627301759028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.726272990045985,
#        'lng': -73.98627301759028},
#       {'label': 'entrance', 'lat': 40.726254, 'lng': -73.986488}],
#      'distance': 2756,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['93 1st Ave (btwn 5th & 6th St)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2208366',
#      'url': 'https://www.seamless.com/menu/panna2-garden-indian-restaurant-93-1st-avenue-new-york/2208366?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2208366',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '149505937'},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4c17b29b838020a1fd0de361',
#     'name': "Bombay's Indian Restaurant",
#     'location': {'address': '60 Pearl St',
#      'crossStreet': 'Broad St.',
#      'lat': 40.70356930142193,
#      'lng': -74.01114087858141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70356930142193,
#        'lng': -74.01114087858141},
#       {'label': 'entrance', 'lat': 40.703503, 'lng': -74.011109}],
#      'distance': 1316,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['60 Pearl St (Broad St.)',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '263979',
#      'url': 'https://www.seamless.com/menu/bombays-indian-restaurant-60-pearl-st-new-york/263979?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=263979',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '93243558'},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '5d13a5df18222300250c8d18',
#     'name': 'Shwarma House Indian Grill',
#     'location': {'lat': 40.703876,
#      'lng': -74.00873,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.703876,
#        'lng': -74.00873}],
#      'distance': 1353,
#      'postalCode': '10041',
#      'cc': 'US',
#      'neighborhood': 'Financial District',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10041', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4f32b59819836c91c7f207fc',
#     'name': 'Karahi Indian Cuisine',
#     'location': {'address': '508 Broome St',
#      'lat': 40.723621,
#      'lng': -74.003124,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.723621,
#        'lng': -74.003124},
#       {'label': 'entrance', 'lat': 40.723535, 'lng': -74.003177}],
#      'distance': 1411,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['508 Broome St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4ae015bff964a5202b7e21e3',
#     'name': 'Swagat Indian',
#     'location': {'address': '205 W 29th St',
#      'crossStreet': '7th Ave',
#      'lat': 40.74804551427938,
#      'lng': -73.99310765459191,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74804551427938,
#        'lng': -73.99310765459191}],
#      'distance': 4133,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['205 W 29th St (7th Ave)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '65014',
#      'url': 'https://www.seamless.com/menu/swagat-indian-restaurant-205-w-29th-st-new-york/65014?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=65014',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4b806ffff964a520457230e3',
#     'name': 'Village Indian Cuisine',
#     'location': {'address': '765 Newark Ave',
#      'crossStreet': 'at John F. Kennedy Blvd',
#      'lat': 40.735251,
#      'lng': -74.06362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.735251,
#        'lng': -74.06362},
#       {'label': 'entrance', 'lat': 40.73534, 'lng': -74.063584}],
#      'distance': 4657,
#      'postalCode': '07306',
#      'cc': 'US',
#      'city': 'Jersey City',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['765 Newark Ave (at John F. Kennedy Blvd)',
#       'Jersey City, NJ 07306',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4b44db0bf964a5204dfe25e3',
#     'name': 'Amin Indian Cuisine',
#     'location': {'address': '235 Dekalb Ave',
#      'crossStreet': 'at Clermont Ave',
#      'lat': 40.68953511109607,
#      'lng': -73.96978773811158,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.68953511109607,
#        'lng': -73.96978773811158}],
#      'distance': 4773,
#      'postalCode': '11205',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['235 Dekalb Ave (at Clermont Ave)',
#       'Brooklyn, NY 11205',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4a60aa67f964a520f9c01fe3',
#     'name': 'Polash Indian restaurant',
#     'location': {'address': '2179 3rd Ave',
#      'crossStreet': 'at 119th St.',
#      'lat': 40.79974477464853,
#      'lng': -73.9387466714612,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79974477464853,
#        'lng': -73.9387466714612},
#       {'label': 'entrance', 'lat': 40.799653, 'lng': -73.938567}],
#      'distance': 11436,
#      'postalCode': '10035',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2179 3rd Ave (at 119th St.)',
#       'New York, NY 10035',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '319303',
#      'url': 'https://www.seamless.com/menu/polash-indian-restaurant-2179-3rd-ave-new-york/319303?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=319303',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4b66280cf964a520bc162be3',
#     'name': 'Indian Taj',
#     'location': {'address': '3723 74th St',
#      'crossStreet': 'btwn Roosevelt & 37th Ave.',
#      'lat': 40.7482070127118,
#      'lng': -73.89165788917562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7482070127118,
#        'lng': -73.89165788917562}],
#      'distance': 11070,
#      'postalCode': '11372',
#      'cc': 'US',
#      'city': 'Jackson Heights',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['3723 74th St (btwn Roosevelt & 37th Ave.)',
#       'Jackson Heights, NY 11372',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '56ed855a498ef3bb022352c3',
#     'name': 'Mughlai Indian Cuisine',
#     'location': {'address': '1724 2nd Ave',
#      'crossStreet': '89th & 90th St',
#      'lat': 40.78020580283837,
#      'lng': -73.95008785684102,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78020580283837,
#        'lng': -73.95008785684102}],
#      'distance': 9112,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1724 2nd Ave (89th & 90th St)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '321971',
#      'url': 'https://www.seamless.com/menu/mughlai-indian-cuisine-1724-2nd-ave-new-york/321971?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=321971',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4e4c4f0bbd413c4cc66864bf',
#     'name': 'Indian Curry Mahal',
#     'location': {'address': '78 2nd Ave',
#      'lat': 40.726337,
#      'lng': -73.98893000000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.726337,
#        'lng': -73.98893000000001},
#       {'label': 'entrance', 'lat': 40.726388, 'lng': -73.989057}],
#      'distance': 2562,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['78 2nd Ave',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '54443e49498ee63c411c794b',
#     'name': 'Moharani Indian Takeaway Restaurant',
#     'location': {'address': '185 Norman Ave',
#      'crossStreet': 'Jewel',
#      'lat': 40.727218,
#      'lng': -73.946919,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.727218,
#        'lng': -73.946919},
#       {'label': 'entrance', 'lat': 40.727143, 'lng': -73.946877}],
#      'distance': 5931,
#      'postalCode': '11222',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['185 Norman Ave (Jewel)',
#       'Brooklyn, NY 11222',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '52a1fa08498ede15b1530912',
#     'name': 'Deep Indian Kitchen',
#     'location': {'address': '25 W 23rd St',
#      'crossStreet': 'btwn 5th & 6th Ave',
#      'lat': 40.742025061405144,
#      'lng': -73.99055792757031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.742025061405144,
#        'lng': -73.99055792757031}],
#      'distance': 3667,
#      'postalCode': '10010',
#      'cc': 'US',
#      'neighborhood': 'NoMad',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['25 W 23rd St (btwn 5th & 6th Ave)',
#       'New York, NY 10010',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '73155260'},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '55b7b61a498ee3b79e225a4a',
#     'name': 'Shawarma House Indian Grill',
#     'location': {'lat': 40.7015982622938,
#      'lng': -74.01119441695305,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7015982622938,
#        'lng': -74.01119441695305}],
#      'distance': 1527,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '50a287a7e4b0033f830f06db',
#     'name': "Raj's Indian Kitchen",
#     'location': {'address': '27-18 Queens Plz S',
#      'lat': 40.74997632892085,
#      'lng': -73.93926056994543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74997632892085,
#        'lng': -73.93926056994543}],
#      'distance': 7508,
#      'postalCode': '11101',
#      'cc': 'US',
#      'city': 'Long Island City',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['27-18 Queens Plz S',
#       'Long Island City, NY 11101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '274919',
#      'url': 'https://www.seamless.com/menu/rajs-indian-kitchen-27-18-queens-plz-s-long-island-city/274919?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=274919',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4e45e718c65bd6ffbe8b4ac7',
#     'name': "Crazy Indian Person's Party",
#     'location': {'address': '200 Mott St.',
#      'lat': 40.721995,
#      'lng': -73.995919,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.721995,
#        'lng': -73.995919}],
#      'distance': 1816,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['200 Mott St.', 'New York', 'United States']},
#     'categories': [],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '59791cf1065ef514acba9ad5',
#     'name': 'American Indian Community House',
#     'location': {'address': '39 Eldridge St',
#      'lat': 40.71569061279297,
#      'lng': -73.99346923828125,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.715667,
#        'lng': -73.993332},
#       {'label': 'display',
#        'lat': 40.71569061279297,
#        'lng': -73.99346923828125}],
#      'distance': 1846,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['39 Eldridge St',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4d44936fc3e5f04d51ff9b20',
#     'name': 'Indian People Deli',
#     'location': {'address': 'Coles St.',
#      'lat': 40.72608,
#      'lng': -74.047921,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72608,
#        'lng': -74.047921}],
#      'distance': 3015,
#      'postalCode': '07302',
#      'cc': 'US',
#      'city': 'Jersey City',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Coles St.',
#       'Jersey City, NJ 07302',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4ab3bc6af964a520386e20e3',
#     'name': 'Minar Indian Restaurant',
#     'location': {'address': '138 W 46th St',
#      'crossStreet': 'btwn 6th Ave & 7th Ave',
#      'lat': 40.758199046480186,
#      'lng': -73.98393847194978,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758199046480186,
#        'lng': -73.98393847194978}],
#      'distance': 5494,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['138 W 46th St (btwn 6th Ave & 7th Ave)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4e42ae367d8bec1e4d1a188b',
#     'name': 'Indian Grill Food Truck',
#     'location': {'crossStreet': 'Frank Sinatra Drive',
#      'lat': 40.737387762314576,
#      'lng': -74.0276741081729,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.737387762314576,
#        'lng': -74.0276741081729}],
#      'distance': 2705,
#      'cc': 'US',
#      'city': 'Hoboken',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Frank Sinatra Drive',
#       'Hoboken, NJ',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4be95a129a54a593f8f00a11',
#     'name': 'Indian Code',
#     'location': {'address': '100 Gold St Apt 2R',
#      'lat': 40.70284632170086,
#      'lng': -73.98311376571655,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70284632170086,
#        'lng': -73.98311376571655}],
#      'distance': 3034,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['100 Gold St Apt 2R',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d125941735',
#       'name': 'Tech Startup',
#       'pluralName': 'Tech Startups',
#       'shortName': 'Tech Startup',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4e4e6a0cbd4101d0d7a9a45a',
#     'name': 'Sangam Authentic Indian Cuisine',
#     'location': {'address': '190 Bleecker St',
#      'lat': 40.72907257080078,
#      'lng': -74.00151062011719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72907257080078,
#        'lng': -74.00151062011719}],
#      'distance': 1957,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['190 Bleecker St',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4cf4591acc61a35d9521259e',
#     'name': 'Yellow Indian Curry Truck',
#     'location': {'lat': 40.72755217552185,
#      'lng': -74.031629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72755217552185,
#        'lng': -74.031629}],
#      'distance': 1963,
#      'cc': 'US',
#      'state': 'New Jersey',
#      'country': 'United States',
#      'formattedAddress': ['New Jersey', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '4bb93b70cf2fc9b6fe64a002',
#     'name': 'Gandhi Fine Indian Cuisine',
#     'location': {'address': '2032 Bedford Ave',
#      'crossStreet': 'btwn Clarkson Ave & Parkside Ave',
#      'lat': 40.65516762218564,
#      'lng': -73.95632450081226,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.65516762218564,
#        'lng': -73.95632450081226}],
#      'distance': 8313,
#      'postalCode': '11226',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2032 Bedford Ave (btwn Clarkson Ave & Parkside Ave)',
#       'Brooklyn, NY 11226',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '275754',
#      'url': 'https://www.seamless.com/menu/gandhi-2032-bedford-ave-brooklyn/275754?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=275754',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '105464962'},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '57a85299498e6ebdbfe34460',
#     'name': 'Indian Astrologer and Love Psychic',
#     'location': {'address': '372 Fulton Street',
#      'lat': 40.69133377075195,
#      'lng': -73.98782348632812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.69133377075195,
#        'lng': -73.98782348632812}],
#      'distance': 3507,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['372 Fulton Street',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b43',
#       'name': 'Astrologer',
#       'pluralName': 'Astrologers',
#       'shortName': 'Astrologer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '226317737'},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '5812605238fac856d076e0ab',
#     'name': 'Halal Indian Food & Falafel',
#     'location': {'address': '6742 5th Ave',
#      'lat': 40.634593,
#      'lng': -74.02085989999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.634593,
#        'lng': -74.02085989999999}],
#      'distance': 8958,
#      'postalCode': '11220',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['6742 5th Ave',
#       'Brooklyn, NY 11220',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10b941735',
#       'name': 'Falafel Restaurant',
#       'pluralName': 'Falafel Restaurants',
#       'shortName': 'Falafel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '317587',
#      'url': 'https://www.seamless.com/menu/halal-indian-food-and-falafel-6742-5th-ave-brooklyn/317587?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=317587',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '58870759297c16611891b792',
#     'name': 'Indian Psychic Spiritual Healer - Astrology',
#     'location': {'address': '465 Fulton St',
#      'lat': 40.691371999999994,
#      'lng': -73.986598,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.691371999999994,
#        'lng': -73.986598},
#       {'label': 'entrance', 'lat': 40.691296, 'lng': -73.986636}],
#      'distance': 3574,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['465 Fulton St',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b43',
#       'name': 'Astrologer',
#       'pluralName': 'Astrologers',
#       'shortName': 'Astrologer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598263650',
#     'hasPerk': False},
#    {'id': '50df8236e4b09e22f537c1b9',
#     'name': 'Pearl Indian Food',
#     'location': {'address': '738 Franklin Ave',
#      'crossStreet': 'at Sterling Pl',
#      'lat': 40.67333006829295,
#      'lng': -73.95715713311526,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.67333006829295,
#        'lng': -73.95715713311526},
#       {'label': 'entrance', 'lat': 40.673193, 'lng': -73.957188}],
#      'distance': 6751,
#      'postalCode': '11238',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['738 Franklin Ave (at Sterling Pl)',
#       'Brooklyn, NY 11238',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '274850',
#      'url': 'https://www.seamless.com/menu/pearl-indian-food-738-franklin-ave-brooklyn/274850?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=274850',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598263650',
#     'hasPerk': False}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ## Let's explore the first Indian Restaurant in our dataframe.

# %%
venues = results['response']['venues'][0]['name']
venues
# Out:
# 'Indian Biryani Delights (Cart)'

# %% [markdown]
# ## In below cells will identify which Postal code the restaurant to be opened by the client

# %%
import json 
from pandas.io.json import json_normalize
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
# 1  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...      275521
# 3  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...         NaN
# 4  [{'id': '52f2ab2ebcbc57f1066b8b1b', 'name': 'S...         NaN
#
#                 delivery.provider.icon.name  \
# 0                                       NaN
# 1                                       NaN
# 2  /delivery_provider_seamless_20180129.png
# 3                                       NaN
# 4                                       NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2               seamless  https://www.seamless.com/menu/a-saffron-thread...
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
#
#    hasPerk                        id location.address  ...  \
# 0    False  5072fe2eb0ed0fcce2497f30         Water St  ...
# 1    False  5d18e90b96ba5e00232c527f              NaN  ...
# 2    False  510aad1ae4b0bfb2583169b9   98 Chambers St  ...
# 3    False  573f435b498e03b8bb8582c7     140 Broadway  ...
# 4    False  54a4690e498e43a77f503eba    1 Bowling Grn  ...
#
#                            location.formattedAddress  \
# 0  [Water St (btwn Maiden Lane & Pine St), New Yo...
# 1                [New York, NY 10007, United States]
# 2  [98 Chambers St (at Church St), New York, NY 1...
# 3  [140 Broadway, New York, NY 10005, United States]
# 4  [1 Bowling Grn, New York, NY 10004, United Sta...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 40.71316451366987...    40.713165
# 1  [{'label': 'display', 'lat': 40.715357202741, ...    40.715357
# 2  [{'label': 'display', 'lat': 40.71482256030567...    40.714823
# 3  [{'label': 'display', 'lat': 40.70253964211186...    40.702540
# 4  [{'label': 'display', 'lat': 40.704048, 'lng':...    40.704048
#
#   location.lng  location.neighborhood location.postalCode location.state  \
# 0   -74.010219                    NaN               10005             NY
# 1   -74.011315                    NaN               10007             NY
# 2   -74.007689                    NaN               10007             NY
# 3   -74.012727                Tribeca               10005             NY
# 4   -74.013737                    NaN               10004             NY
#
#                                                 name    referralId  \
# 0                     Indian Biryani Delights (Cart)  v-1598263650
# 1                      Bismilla Indian Biryani House  v-1598263650
# 2                      A Saffron Thread Fresh Indian  v-1598263650
# 3                         Indian king Biriyani House  v-1598263650
# 4  National Museum of the American Indian Museum ...  v-1598263650
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2    432263795
# 3          NaN
# 4          NaN
#
# [5 rows x 25 columns]

# %%
dataframe[["name","location.neighborhood","location.city","location.postalCode","location.labeledLatLngs"]]
# Out:
#                                                  name location.neighborhood  \
# 0                      Indian Biryani Delights (Cart)                   NaN
# 1                       Bismilla Indian Biryani House                   NaN
# 2                       A Saffron Thread Fresh Indian                   NaN
# 3                          Indian king Biriyani House               Tribeca
# 4   National Museum of the American Indian Museum ...                   NaN
# 5              National Museum of the American Indian                   NaN
# 6           Indian Beautiful Art (IBA) Crafts PVT Ltd                   NaN
# 7                                      Indian Express                   NaN
# 8           Indian Beautiful Art (IBA) Crafts PVT Ltd                   NaN
# 9                              Asya Indian Restaurant                   NaN
# 10                               Aahar Indian Cuisine                   NaN
# 11                                   Baluchi's Indian                   NaN
# 12                               Ruchi Indian Cuisine                   NaN
# 13                               Indian Biryani House                   NaN
# 14                       Indian Grill & Biryani House                   NaN
# 15                               Indian Biryani House                   NaN
# 16                               smart indian cuisine                   NaN
# 17                       Indian Larry Motorcycles NYC                   NaN
# 18                                  Indian Restaurant                   NaN
# 19                CKGS Indian Visa Application Center                   NaN
# 20                                  Indian Food Truck                   NaN
# 21                              Indian fast food cart                   NaN
# 22                  Panna II Garden Indian Restaurant                   NaN
# 23                         Bombay's Indian Restaurant                   NaN
# 24                         Shwarma House Indian Grill    Financial District
# 25                              Karahi Indian Cuisine                   NaN
# 26                                      Swagat Indian                   NaN
# 27                             Village Indian Cuisine                   NaN
# 28                                Amin Indian Cuisine                   NaN
# 29                           Polash Indian restaurant                   NaN
# 30                                         Indian Taj                   NaN
# 31                             Mughlai Indian Cuisine                   NaN
# 32                                 Indian Curry Mahal                   NaN
# 33                Moharani Indian Takeaway Restaurant                   NaN
# 34                                Deep Indian Kitchen                 NoMad
# 35                        Shawarma House Indian Grill                   NaN
# 36                               Raj's Indian Kitchen                   NaN
# 37                        Crazy Indian Person's Party                   NaN
# 38                    American Indian Community House                   NaN
# 39                                 Indian People Deli                   NaN
# 40                            Minar Indian Restaurant                   NaN
# 41                            Indian Grill Food Truck                   NaN
# 42                                        Indian Code                   NaN
# 43                    Sangam Authentic Indian Cuisine                   NaN
# 44                          Yellow Indian Curry Truck                   NaN
# 45                         Gandhi Fine Indian Cuisine                   NaN
# 46                 Indian Astrologer and Love Psychic                   NaN
# 47                        Halal Indian Food & Falafel                   NaN
# 48        Indian Psychic Spiritual Healer - Astrology                   NaN
# 49                                  Pearl Indian Food                   NaN
#
#        location.city location.postalCode  \
# 0           New York               10005
# 1           New York               10007
# 2           New York               10007
# 3           New York               10005
# 4           New York               10004
# 5           New York               10004
# 6           New York               10007
# 7           New York               10007
# 8           New York               10007
# 9           Brooklyn               11201
# 10          New York               10007
# 11          New York                 NaN
# 12          New York               10006
# 13          New York               10014
# 14          New York               10004
# 15          New York                 NaN
# 16          New York               10038
# 17          Brooklyn               11222
# 18          New York               10013
# 19          New York               10011
# 20       Jersey City                 NaN
# 21          New York               10022
# 22          New York               10003
# 23          New York               10004
# 24          New York               10041
# 25          New York               10013
# 26          New York               10001
# 27       Jersey City               07306
# 28          Brooklyn               11205
# 29          New York               10035
# 30   Jackson Heights               11372
# 31          New York               10128
# 32          New York               10003
# 33          Brooklyn               11222
# 34          New York               10010
# 35          New York                 NaN
# 36  Long Island City               11101
# 37               NaN                 NaN
# 38          New York               10002
# 39       Jersey City               07302
# 40          New York               10036
# 41           Hoboken                 NaN
# 42          Brooklyn               11201
# 43          New York               10012
# 44               NaN                 NaN
# 45          Brooklyn               11226
# 46          Brooklyn               11201
# 47          Brooklyn               11220
# 48          Brooklyn               11201
# 49          Brooklyn               11238
#
#                               location.labeledLatLngs
# 0   [{'label': 'display', 'lat': 40.71316451366987...
# 1   [{'label': 'display', 'lat': 40.715357202741, ...
# 2   [{'label': 'display', 'lat': 40.71482256030567...
# 3   [{'label': 'display', 'lat': 40.70253964211186...
# 4   [{'label': 'display', 'lat': 40.704048, 'lng':...
# 5   [{'label': 'display', 'lat': 40.7043035374255,...
# 6   [{'label': 'display', 'lat': 40.71228057311295...
# 7   [{'label': 'display', 'lat': 40.71341323852539...
# 8   [{'label': 'display', 'lat': 40.71613521878094...
# 9   [{'label': 'display', 'lat': 40.699607, 'lng':...
# 10  [{'label': 'display', 'lat': 40.71330656515891...
# 11  [{'label': 'display', 'lat': 40.71567153930664...
# 12  [{'label': 'display', 'lat': 40.70996196046026...
# 13  [{'label': 'display', 'lat': 40.728253, 'lng':...
# 14  [{'label': 'display', 'lat': 40.70424479657133...
# 15  [{'label': 'display', 'lat': 40.704955, 'lng':...
# 16  [{'label': 'display', 'lat': 40.709022, 'lng':...
# 17  [{'label': 'display', 'lat': 40.71232231166012...
# 18  [{'label': 'display', 'lat': 40.71997833251953...
# 19  [{'label': 'display', 'lat': 40.74472518293832...
# 20  [{'label': 'display', 'lat': 40.71289231329906...
# 21  [{'label': 'display', 'lat': 40.75946861543554...
# 22  [{'label': 'display', 'lat': 40.72627299004598...
# 23  [{'label': 'display', 'lat': 40.70356930142193...
# 24  [{'label': 'display', 'lat': 40.703876, 'lng':...
# 25  [{'label': 'display', 'lat': 40.723621, 'lng':...
# 26  [{'label': 'display', 'lat': 40.74804551427938...
# 27  [{'label': 'display', 'lat': 40.735251, 'lng':...
# 28  [{'label': 'display', 'lat': 40.68953511109607...
# 29  [{'label': 'display', 'lat': 40.79974477464853...
# 30  [{'label': 'display', 'lat': 40.7482070127118,...
# 31  [{'label': 'display', 'lat': 40.78020580283837...
# 32  [{'label': 'display', 'lat': 40.726337, 'lng':...
# 33  [{'label': 'display', 'lat': 40.727218, 'lng':...
# 34  [{'label': 'display', 'lat': 40.74202506140514...
# 35  [{'label': 'display', 'lat': 40.7015982622938,...
# 36  [{'label': 'display', 'lat': 40.74997632892085...
# 37  [{'label': 'display', 'lat': 40.721995, 'lng':...
# 38  [{'label': 'entrance', 'lat': 40.715667, 'lng'...
# 39  [{'label': 'display', 'lat': 40.72608, 'lng': ...
# 40  [{'label': 'display', 'lat': 40.75819904648018...
# 41  [{'label': 'display', 'lat': 40.73738776231457...
# 42  [{'label': 'display', 'lat': 40.70284632170086...
# 43  [{'label': 'display', 'lat': 40.72907257080078...
# 44  [{'label': 'display', 'lat': 40.72755217552185...
# 45  [{'label': 'display', 'lat': 40.65516762218564...
# 46  [{'label': 'display', 'lat': 40.69133377075195...
# 47  [{'label': 'display', 'lat': 40.634593, 'lng':...
# 48  [{'label': 'display', 'lat': 40.69137199999999...
# 49  [{'label': 'display', 'lat': 40.67333006829295...

# %% [markdown]
# ## As Neighborhood is not provided in Foursquare data for all records we will use postal code to shortlist the area where the client has to open his Indian Restaurant

# %%
df1 = dataframe[dataframe['location.city'] == 'New York'].reset_index(drop=True)

# %% [markdown]
# Let us see few columns of data with Postal code

# %%
df1[['name','location.lat','location.lng',"location.city","location.postalCode"]]
# Out:
#                                                  name  location.lat  \
# 0                      Indian Biryani Delights (Cart)     40.713165
# 1                       Bismilla Indian Biryani House     40.715357
# 2                       A Saffron Thread Fresh Indian     40.714823
# 3                          Indian king Biriyani House     40.702540
# 4   National Museum of the American Indian Museum ...     40.704048
# 5              National Museum of the American Indian     40.704304
# 6           Indian Beautiful Art (IBA) Crafts PVT Ltd     40.712281
# 7                                      Indian Express     40.713413
# 8           Indian Beautiful Art (IBA) Crafts PVT Ltd     40.716135
# 9                                Aahar Indian Cuisine     40.713307
# 10                                   Baluchi's Indian     40.715672
# 11                               Ruchi Indian Cuisine     40.709962
# 12                               Indian Biryani House     40.728253
# 13                       Indian Grill & Biryani House     40.704245
# 14                               Indian Biryani House     40.704955
# 15                               smart indian cuisine     40.709022
# 16                                  Indian Restaurant     40.719978
# 17                CKGS Indian Visa Application Center     40.744725
# 18                              Indian fast food cart     40.759469
# 19                  Panna II Garden Indian Restaurant     40.726273
# 20                         Bombay's Indian Restaurant     40.703569
# 21                         Shwarma House Indian Grill     40.703876
# 22                              Karahi Indian Cuisine     40.723621
# 23                                      Swagat Indian     40.748046
# 24                           Polash Indian restaurant     40.799745
# 25                             Mughlai Indian Cuisine     40.780206
# 26                                 Indian Curry Mahal     40.726337
# 27                                Deep Indian Kitchen     40.742025
# 28                        Shawarma House Indian Grill     40.701598
# 29                    American Indian Community House     40.715691
# 30                            Minar Indian Restaurant     40.758199
# 31                    Sangam Authentic Indian Cuisine     40.729073
#
#     location.lng location.city location.postalCode
# 0     -74.010219      New York               10005
# 1     -74.011315      New York               10007
# 2     -74.007689      New York               10007
# 3     -74.012727      New York               10005
# 4     -74.013737      New York               10004
# 5     -74.013759      New York               10004
# 6     -74.010129      New York               10007
# 7     -74.008469      New York               10007
# 8     -74.006610      New York               10007
# 9     -74.007994      New York               10007
# 10    -74.007652      New York                 NaN
# 11    -74.012969      New York               10006
# 12    -74.007321      New York               10014
# 13    -74.009117      New York               10004
# 14    -74.013003      New York                 NaN
# 15    -74.009117      New York               10038
# 16    -73.995903      New York               10013
# 17    -73.996796      New York               10011
# 18    -73.972256      New York               10022
# 19    -73.986273      New York               10003
# 20    -74.011141      New York               10004
# 21    -74.008730      New York               10041
# 22    -74.003124      New York               10013
# 23    -73.993108      New York               10001
# 24    -73.938747      New York               10035
# 25    -73.950088      New York               10128
# 26    -73.988930      New York               10003
# 27    -73.990558      New York               10010
# 28    -74.011194      New York                 NaN
# 29    -73.993469      New York               10002
# 30    -73.983938      New York               10036
# 31    -74.001511      New York               10012

# %%
df1.sort_values(by=['location.postalCode'], inplace=True)

# %%
df1['location.postalCode']
# Out:
# 23    10001
# 29    10002
# 26    10003
# 19    10003
# 20    10004
# 13    10004
# 4     10004
# 5     10004
# 0     10005
# 3     10005
# 11    10006
# 7     10007
# 6     10007
# 2     10007
# 1     10007
# 8     10007
# 9     10007
# 27    10010
# 17    10011
# 31    10012
# 22    10013
# 16    10013
# 12    10014
# 18    10022
# 24    10035
# 30    10036
# 15    10038
# 21    10041
# 25    10128
# 10      NaN
# 14      NaN
# 28      NaN
# Name: location.postalCode, dtype: object

# %%
df1[['location.postalCode']].groupby(['location.postalCode']).size()
# Out:
# location.postalCode
# 10001    1
# 10002    1
# 10003    2
# 10004    4
# 10005    2
# 10006    1
# 10007    6
# 10010    1
# 10011    1
# 10012    1
# 10013    2
# 10014    1
# 10022    1
# 10035    1
# 10036    1
# 10038    1
# 10041    1
# 10128    1
# dtype: int64

# %% [markdown]
# # Concluding that the Stake holder to open the restaurant in Postalcode 10007 as it has maximum number of Indian restaurants with MSA name as New York-Northern New Jersey-Long Island, NY-NJ-CT-PA
